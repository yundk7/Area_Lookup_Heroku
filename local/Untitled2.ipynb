# %%
import pandas as pd
# from sqlalchemy import create_engine
import requests
import json
import math

# %%
from sqlalchemy import create_engine
from bs4 import BeautifulSoup as bs

# %%
df = google_geo(["235 w van buren"],"restaurant",1000)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-413ed95d75f5> in <module>
# ----> 1 df = google_geo(["235 w van buren"],"restaurant",1000)
#
# <ipython-input-9-8c3bc483d11d> in google_geo(srch_list, pois, radius)
#      10         target_url = (f'https://maps.googleapis.com/maps/api/geocode/json?address={s}&key={gkey}')
#      11         geo_data = requests.get(target_url).json()
# ---> 12         target_adr = geo_data["results"][0]["formatted_address"]
#      13         lat = geo_data["results"][0]["geometry"]["location"]["lat"]
#      14         lng = geo_data["results"][0]["geometry"]["location"]["lng"]
#
# IndexError: list index out of range

# %%
gkey = "AIzaSyCx9a5SZ-y42Wu2fQeqmHsfKFRk4djJsAs"
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
            "location": "37.5172, 127.0473",
            "keyword": "초밥",
            "radius": radius,
        #     "type": target_type,
            "key": gkey
        }
api = requests.get(base_url, params=params).json()

# %%
api
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCHQEAAHhCuh5H0hV4F_vsPcxBHrsP7Ce4duJVV_hjfYFN26T7UCi-eyeWF4LAmfHTj8_cjXheI-8cd7f16bugy-2o0UfTI7DmKEmEq8F-8sa_MG16WLfc9pgCIDIAUn-Yi3XNiLPY-enZBidC_EH5B02S_8nltyZolrk1DQ_-ZM7uEgGMmK8WiycqK-XKDBdC59Efh_RtzywnTJjpEXSVlp5dxCVruMjxqmakhgLdULyAhZ3Enhn30Ib1OTtxkCVcLYM7xbaDjeECEfmVZ96LZhf0qxngZ27UIA97g4_-olhe-EHMqhC8QpPborhXiztRNXLgQzF8YpNjEMcAfbhRhmRf4RW3LrwHMkVPsETA15zQOH2_NwlivNxy4xV_hpWxIZ5LkxIQCsqNME3tQOMvunr1V7OxehoUiwexaimdFibNiBM8rW8H95bVe-Y',
#  'results': [{'geometry': {'location': {'lat': 37.5149869, 'lng': 127.0526864},
#     'viewport': {'northeast': {'lat': 37.51633672989271,
#       'lng': 127.0540362298927},
#      'southwest': {'lat': 37.51363707010727, 'lng': 127.0513365701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '8a5945f8fb611c216cdc21487d3b2d5e69b668b8',
#    'name': '스시히로바',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114979556987614397107">1 23</a>'],
#      'photo_reference': 'CmRaAAAAbZg19MXy2-7-J80stR5-9BgUacWQVx0hsBeZb8kHwowWRffJXkRBwOutm82AmhzSRb6gSzjZcBLAg4lr3OVddVUdaoSfZs-2x1Ybbmt-CrvIpMnGSw0XGAPVfmFGkRl0EhDizcK7WBe06JE0I-K1CChRGhShLEfc_fxzbMpltHVskknWK6DTrg',
#      'width': 4032}],
#    'place_id': 'ChIJ-6b3uG2kfDUR7AD2Qvn-oUA',
#    'plus_code': {'compound_code': 'G373+X3 Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G373+X3'},
#    'price_level': 3,
#    'rating': 3.9,
#    'reference': 'ChIJ-6b3uG2kfDUR7AD2Qvn-oUA',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 607,
#    'vicinity': 'Gangnam-gu, 삼성동 70'},
#   {'geometry': {'location': {'lat': 37.52206109999999, 'lng': 127.0418667},
#     'viewport': {'northeast': {'lat': 37.52341092989272,
#       'lng': 127.0432165298927},
#      'southwest': {'lat': 37.52071127010728, 'lng': 127.0405168701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'd9ef230a3e031a07f6cd8065935cb1a97f86a155',
#    'name': 'Sushi Hyo, Cheongdam',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103184673647564038957">Taekyun Koo</a>'],
#      'photo_reference': 'CmRaAAAAdaksBWXfQG1fkt7GGW_Lqodcx8iIAnFAorphw_uyraydMV2zQxEZO9CWeeCkPd5UKq2KjV5-4iuQwkkcLYui4UqPXeXCEs22ThxkdnGn2cn4ES4tBGM8BPr-i_qJDs-xEhAklHTZXEPnnor3QC39Rs2SGhRpZJORnf_Bl2xQiAtY0HAsxpjnkg',
#      'width': 4032}],
#    'place_id': 'ChIJObGLTnakfDURvMegnvAwXDA',
#    'plus_code': {'compound_code': 'G2CR+RP Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G2CR+RP'},
#    'price_level': 4,
#    'rating': 4.4,
#    'reference': 'ChIJObGLTnakfDURvMegnvAwXDA',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 360,
#    'vicinity': '25 Seolleung-ro 146-gil, Cheongdam-dong, Gangnam-gu'},
#   {'geometry': {'location': {'lat': 37.5151478, 'lng': 127.0357398},
#     'viewport': {'northeast': {'lat': 37.51649762989272,
#       'lng': 127.0370896298927},
#      'southwest': {'lat': 37.51379797010728, 'lng': 127.0343899701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'f975d9170d7f4b83bc3f2b5e4e1824837c183f94',
#    'name': 'Danseusi',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101256747828613397177">Soo Jin Park</a>'],
#      'photo_reference': 'CmRaAAAA21MP1egMmrrND35vTQpMcoYtAZF04EOczANfTr9FDOL-BwJfoVscavueKuWVMFvKBg9bRyNFnzQgPX4SM0CgwzFB3iuJ9VsNYzMxfuSCjp0viYa6RBqqrQnUxiHlb7MyEhAcYY0W-BvPU2jlWggKyeEHGhTRDjXFs8Pz79btKeU_0xXe7ftxUQ',
#      'width': 3024}],
#    'place_id': 'ChIJjzxLYfSjfDUR8Qn41wre_kE',
#    'plus_code': {'compound_code': 'G28P+37 Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G28P+37'},
#    'rating': 3.7,
#    'reference': 'ChIJjzxLYfSjfDUR8Qn41wre_kE',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 236,
#    'vicinity': '238 Nonhyeon-dong, Gangnam-gu'},
#   {'geometry': {'location': {'lat': 37.5226989, 'lng': 127.0476372},
#     'viewport': {'northeast': {'lat': 37.52404872989272,
#       'lng': 127.0489870298927},
#      'southwest': {'lat': 37.52134907010728, 'lng': 127.0462873701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '4cca3b7c72ae43ff280c4adcc4d011e30d31e193',
#    'name': '스테파노 일류초밥(Stephano Illyu Sushi)',
#    'photos': [{'height': 2736,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112832775705695251124">Disney Bug</a>'],
#      'photo_reference': 'CmRaAAAAyzbct2jOL7YGv-3gfuQIfUhPYq5QS1PkIHSNp72sm_IFqZ5G61hf0i133N9vTpzBtuxg5a4-yTO2OFfXIMAE5p7vS5_JWYUPgIJWKZlWWzvk5xZj4NQLkaQrR8gTVGfzEhAl8vgxxAGcUflLCP7ZKLdyGhR1ph65mlPfnEhM_TmryP_E0dxYGw',
#      'width': 4032}],
#    'place_id': 'ChIJlTjseHqkfDURWYgm55R4PQU',
#    'plus_code': {'compound_code': 'G2FX+33 Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G2FX+33'},
#    'rating': 4.1,
#    'reference': 'ChIJlTjseHqkfDURWYgm55R4PQU',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 8,
#    'vicinity': '4 Samseong-ro 147-gil, Cheongdam-dong, Gangnam-gu'},
#   {'geometry': {'location': {'lat': 37.522832, 'lng': 127.036421},
#     'viewport': {'northeast': {'lat': 37.52418182989273,
#       'lng': 127.0377708298927},
#      'southwest': {'lat': 37.52148217010729, 'lng': 127.0350711701072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'e2bb99a401ef9c4cd27a7b229c20caa3db66cc76',
#    'name': 'Sushi Sunsoo',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102245089251553852795">Hana Lee</a>'],
#      'photo_reference': 'CmRaAAAAxiDndU-kHxXC7llBuNqaov-monp3Vv2DN-2FrgDC-mJLbzYxKVNshRVUAirhFjtrxbWkQ92-3BlIGCVwJM6Q5WC9glClpZWwWUy3vKPOjONzKbqTzBIgTgO6zDvGY1ZEEhAfKqH4e3eoCkqIS5en3pqOGhRmJ7IfBxX39sE1R2LtLgZz9pSc-w',
#      'width': 2988}],
#    'place_id': 'ChIJg7vdbomjfDUR1rxPKeYeSpI',
#    'plus_code': {'compound_code': 'G2FP+4H Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G2FP+4H'},
#    'price_level': 4,
#    'rating': 4.5,
#    'reference': 'ChIJg7vdbomjfDUR1rxPKeYeSpI',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 233,
#    'vicinity': '6 Dosan-daero 45-gil, Sinsa-dong, Gangnam-gu'},
#   {'geometry': {'location': {'lat': 37.5095266, 'lng': 127.0373023},
#     'viewport': {'northeast': {'lat': 37.51087642989273,
#       'lng': 127.0386521298927},
#      'southwest': {'lat': 37.50817677010728, 'lng': 127.0359524701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '65c84842c44ce24b83a84cc60d6694686732906f',
#    'name': 'Seusigan',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111876363337822989042">스시간</a>'],
#      'photo_reference': 'CmRaAAAAQbyjo0o--Q4UaM5onxsXMO3D0_j_PHud-FXCRZDq2u_BMbOJSxEQr7RtDPJGQAwTX5oWY3J1Yu6wsQmfIn_b2tcV-kHD8yXU95wvP8yVqO9Qf3aNSEagtp1yL0bOse2JEhD2F9Jnr3tkGT8dbrt_F3CSGhSLvIaOjFjwzibwRPvfPaQiKc-p-Q',
#      'width': 1440}],
#    'place_id': 'ChIJd619qfejfDURlR07TA6g0DQ',
#    'plus_code': {'compound_code': 'G25P+RW Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G25P+RW'},
#    'rating': 4.3,
#    'reference': 'ChIJd619qfejfDURlR07TA6g0DQ',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 49,
#    'vicinity': 'Gangnam-gu, Nonhyeon 2(i)-dong, 237- 5 스시간 1층'},
#   {'geometry': {'location': {'lat': 37.5225963, 'lng': 127.0405702},
#     'viewport': {'northeast': {'lat': 37.52394612989272,
#       'lng': 127.0419200298927},
#      'southwest': {'lat': 37.52124647010728, 'lng': 127.0392203701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'e9e944b06792b696318955121015b2af5cc75db6',
#    'name': '다온초밥',
#    'photos': [{'height': 3648,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102516575514998181602">옥상훈</a>'],
#      'photo_reference': 'CmRaAAAASR_AcBRknEmUf1PIQunxiFAvG6lvbXPm4-sXh0imP2ToThhE-EmIV3Ml8WEsBuLpnb7an3Vonh7MQaSbY9y4JCpfEkElsRg8ZElwpa66Er-hLmU_h92ystUcdOIWUO33EhB6LOjVZd-PZs5ouOCUqEDNGhSkgZYLgvPL3lsj7QkHAjiDWZnETw',
#      'width': 5472}],
#    'place_id': 'ChIJl4d_VemjfDURh2eW6iUqGpg',
#    'plus_code': {'compound_code': 'G2FR+26 Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G2FR+26'},
#    'rating': 3.5,
#    'reference': 'ChIJl4d_VemjfDURh2eW6iUqGpg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 27,
#    'vicinity': '11 Seolleung-ro 148-gil, Cheongdam-dong, Gangnam-gu'},
#   {'geometry': {'location': {'lat': 37.5253843, 'lng': 127.0498034},
#     'viewport': {'northeast': {'lat': 37.52673412989272,
#       'lng': 127.0511532298927},
#      'southwest': {'lat': 37.52403447010727, 'lng': 127.0484535701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '022013a81fda04b2d515090b04151b4218aa2f30',
#    'name': 'Jung Sushi',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115983622184116726942">BB Y</a>'],
#      'photo_reference': 'CmRaAAAAtdc9sSSL8-gYM3i4kiR13BailNw__gH09BAz8wqy5MK7zJpiSfqx0c9bxL97Gw_X0_Z6pxZsvyGJsqki9p_rV7zXQLCgApBd_mFOD7DhAhNj1R-28eOqdpMwq7SQUTnkEhCpdjMU12xZB-EKuTU2gFg-GhQPYhU5SbInJbduhTcfvrCa1AnvAw',
#      'width': 4032}],
#    'place_id': 'ChIJI-dYs2SkfDUR614Bc6h2JDA',
#    'plus_code': {'compound_code': 'G2GX+5W Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G2GX+5W'},
#    'rating': 3.9,
#    'reference': 'ChIJI-dYs2SkfDUR614Bc6h2JDA',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 87,
#    'vicinity': '122-30 Cheongdam-dong, Gangnam-gu'},
#   {'geometry': {'location': {'lat': 37.5164645, 'lng': 127.0400498},
#     'viewport': {'northeast': {'lat': 37.51781432989272,
#       'lng': 127.0413996298927},
#      'southwest': {'lat': 37.51511467010727, 'lng': 127.0386999701072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'f9755b2eca3a87b3fb24a77cfff98d74f8a87921',
#    'name': 'Sushi Namiki',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108467665284809608401">이용</a>'],
#      'photo_reference': 'CmRaAAAAGnpMl3E30UFDw8vi8xSwKnMXjdbEpSQ1s_5aHW5YNtqNtAK4Wv21_XR9sWmM3xBFqjUSYEb2-XUpJ9l44GDiU_JL7jvawQJ0HKqFXuIUjKLxsem0WoICg8GgxXw1EHhtEhAMjbJoX459mS9EfvXVJ4FKGhQ5at-3CSfVJ6YW3WymzQkhV8CBmg',
#      'width': 4032}],
#    'place_id': 'ChIJO3UDVnWkfDURvvTtbUakXyg',
#    'plus_code': {'compound_code': 'G28R+H2 Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G28R+H2'},
#    'rating': 4.5,
#    'reference': 'ChIJO3UDVnWkfDURvvTtbUakXyg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 64,
#    'vicinity': 'Gangnam-gu, Nonhyeon 2(i)-dong, 학동로 338 강남파라곤 103호'},
#   {'geometry': {'location': {'lat': 37.5241728, 'lng': 127.0366078},
#     'viewport': {'northeast': {'lat': 37.52552262989272,
#       'lng': 127.0379576298927},
#      'southwest': {'lat': 37.52282297010728, 'lng': 127.0352579701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '37a30c524ba6293a46e5962dd38b8708efe92b99',
#    'name': '스시기요세 (Sushi Kiyose)',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117928962793602597431">jaehan p</a>'],
#      'photo_reference': 'CmRaAAAAOCs9dS4Oyk4k96X7aNHLNjaO9KO6-rfioY_ad0A--vmdJPhiJxkIdXRjCDZYZ-__Kccq2osnsIRhd1C-Fd2FzvOTc_C5HYvQSmCb0Cf7TlcNOJiX-MWOwWcAQN3KtlzmEhAYHcd8428GhNZ7YEFZ0ScEGhRuZtmzIbjKREcmN5DQOofBg8Qmnw',
#      'width': 3024}],
#    'place_id': 'ChIJqf3eHImjfDUR93n0G9NW-d8',
#    'plus_code': {'compound_code': 'G2FP+MJ Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G2FP+MJ'},
#    'price_level': 4,
#    'rating': 4.4,
#    'reference': 'ChIJqf3eHImjfDUR93n0G9NW-d8',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 15,
#    'vicinity': '65-2 Apgujeong-ro 46-gil, Apgujeong-dong, Gangnam-gu'},
#   {'geometry': {'location': {'lat': 37.51228589999999, 'lng': 127.0576921},
#     'viewport': {'northeast': {'lat': 37.51363572989273,
#       'lng': 127.0590419298927},
#      'southwest': {'lat': 37.51093607010728, 'lng': 127.0563422701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'f92ca90d411f07b58888d320ceaa812e3e5dde8d',
#    'name': 'Sushiro',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103106559555391059422">Dongwon Oh</a>'],
#      'photo_reference': 'CmRaAAAAacorPN5Pa5CWCPuCNkipspBXBfJ-hK83Aj2j1yeAPwUMf-NENPEPgm3zK1RDhZ31ptFBMSi1lA5tFYWhTo1xaW-i7jicg4iV1CAlktJQHXiL7XV42e7sBLAnJtaeaH4dEhCFXx3y10qYibnKqyLxMf0nGhTiWh-N3eA_F6y9oeEs6PZY7-AHQA',
#      'width': 4032}],
#    'place_id': 'ChIJeeRkoWukfDURxeCigIr7msA',
#    'plus_code': {'compound_code': 'G365+W3 Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G365+W3'},
#    'rating': 3.6,
#    'reference': 'ChIJeeRkoWukfDURxeCigIr7msA',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 178,
#    'vicinity': '46 Teheran-ro 87-gil, Samseong 1(il)-dong, Gangnam-gu'},
#   {'geometry': {'location': {'lat': 37.525629, 'lng': 127.0345232},
#     'viewport': {'northeast': {'lat': 37.52697882989271,
#       'lng': 127.0358730298927},
#      'southwest': {'lat': 37.52427917010727, 'lng': 127.0331733701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '2b85be37bc6cc2c0132ef48498a48bab56e1080b',
#    'name': 'Seusiin',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103803069155565114071">Den Sunoo</a>'],
#      'photo_reference': 'CmRaAAAA-XS3JPCo7vCsF8sUXs0ymBy5_KZq7EHIztnjUa4hyGv6QrA0ZRPwACQ4RC069kzfYub8lfyh5pAmQCxrzYpEbxJrGnBF1HZSNtbYZNTjtWxuqf3eEuLZvXO266gD8edXEhD_xpER2PGMQ54CMxxyU-92GhTHUaL4ERebcdcwA5yxhjkuktBNgQ',
#      'width': 4032}],
#    'place_id': 'ChIJXQ56LY-jfDUR4aomQsW9sbY',
#    'plus_code': {'compound_code': 'G2GM+7R Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G2GM+7R'},
#    'price_level': 4,
#    'rating': 4.7,
#    'reference': 'ChIJXQ56LY-jfDUR4aomQsW9sbY',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 76,
#    'vicinity': '49 Apgujeong-ro 42-gil, Sinsa-dong, Gangnam-gu'},
#   {'geometry': {'location': {'lat': 37.5088515, 'lng': 127.0438462},
#     'viewport': {'northeast': {'lat': 37.51020132989272,
#       'lng': 127.0451960298927},
#      'southwest': {'lat': 37.50750167010728, 'lng': 127.0424963701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'b599a343a191b4cad185dcc743080c7c4b160733',
#    'name': 'Seusiki',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109071063681397345344">B. JUN KIM</a>'],
#      'photo_reference': 'CmRaAAAABYjLF6Q28_WzXuDaXoSYySKbOrihZZ18VNQQ1u83SSTdjzEYE3u29LZ2m6Hf7HSE_8umiGumLnjn1lDQHn7qP9Jrf8RdagHOfjTXLOIrrOPA038Xaq71J2shZWAsw0ieEhBAcbGhWRZEWvsOj4J7jaEPGhSVFCtRmKFOdkVcmBcLmOm7_xjZ9g',
#      'width': 4032}],
#    'place_id': 'ChIJmeP3FAmkfDUR_hSOOEL1AZQ',
#    'plus_code': {'compound_code': 'G25V+GG Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G25V+GG'},
#    'price_level': 4,
#    'rating': 4.7,
#    'reference': 'ChIJmeP3FAmkfDUR_hSOOEL1AZQ',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 68,
#    'vicinity': '683-2 Yeoksam 1(il)-dong, Gangnam-gu'},
#   {'geometry': {'location': {'lat': 37.52515959999999, 'lng': 127.045704},
#     'viewport': {'northeast': {'lat': 37.52650942989271,
#       'lng': 127.0470538298927},
#      'southwest': {'lat': 37.52380977010727, 'lng': 127.0443541701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'a8d441b9ab40ca43a0b0bbafd6d37953e30748d3',
#    'name': '스시카나에',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115734573516182360131">Jeongheon Kim</a>'],
#      'photo_reference': 'CmRaAAAAEq64eoHV9oB3Wi8XxLr3lP68R0dKw7NDSDFhZD1yU7_aw2PHIwtasN2ZAg9diYpp-_xCV3naIh_vvwWMgeWjlPAHWrL4wrT9UuM2zD5p1dvcXI3Dyg216UhSNZOenqzlEhBBNQg0KpoqCK3aRHZ5dlbtGhTYcE8_PDBrEFx4e_SNxNT_D_kQ_A',
#      'width': 3024}],
#    'place_id': 'ChIJMT2503ylfDURLaPEXxKciy0',
#    'plus_code': {'compound_code': 'G2GW+37 Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G2GW+37'},
#    'rating': 4.6,
#    'reference': 'ChIJMT2503ylfDURLaPEXxKciy0',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 69,
#    'vicinity': '96-22 Cheongdam-dong, Gangnam-gu'},
#   {'geometry': {'location': {'lat': 37.523725, 'lng': 127.0359559},
#     'viewport': {'northeast': {'lat': 37.52507482989272,
#       'lng': 127.0373057298927},
#      'southwest': {'lat': 37.52237517010727, 'lng': 127.0346060701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'df24ab32b84e29a29aa8e33cc684825bbd1f9bb7',
#    'name': '스시 초희',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103803069155565114071">Den Sunoo</a>'],
#      'photo_reference': 'CmRaAAAAMu3h4Fwkusv-RAD-EKowXYwGBkJWtkIekxNqEkihtjhdu2HkBdODNM-Lwx84oFRE2OrulRWEmoPnKK9xYyfzRvKR4hD4if1ZBjlEQPdcmfBNMl4W4NCQDf9_nr8THJWTEhC0XvGuSj0e60U7BzTokNd4GhQ83GQVULUyTckxQT6b61Nf392yyQ',
#      'width': 4032}],
#    'place_id': 'ChIJiVXkPYmjfDURUUtag1TdCYU',
#    'plus_code': {'compound_code': 'G2FP+F9 Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G2FP+F9'},
#    'price_level': 4,
#    'rating': 4.1,
#    'reference': 'ChIJiVXkPYmjfDURUUtag1TdCYU',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 97,
#    'vicinity': '18-6 Dosan-daero 45-gil, Sinsa-dong, Gangnam-gu'},
#   {'geometry': {'location': {'lat': 37.5245905, 'lng': 127.0405571},
#     'viewport': {'northeast': {'lat': 37.52594032989272,
#       'lng': 127.0419069298927},
#      'southwest': {'lat': 37.52324067010728, 'lng': 127.0392072701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '71a437a35de6b5e01e2676a8641f49805ab2a301',
#    'name': '스시 스미레',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117928962793602597431">jaehan p</a>'],
#      'photo_reference': 'CmRaAAAAMoOuwo41JW3pwYrCZReNQ1mq6DiS5wUKBwIpU82y1GQJqaiNdeJLLaFhFS6PHwBgNAOUAf1RQ5JV2H0toUVJLLJxCTZkqDyudmp_npTU5a0_UzxVt-vBG7g0pDiTPh3QEhC3qzHkPadYMGw88lb5W2ATGhTrVRa-YzPhpag1LmUEGzZoDCXbYg',
#      'width': 4032}],
#    'place_id': 'ChIJ55z2kUelfDURRm5aBsQ7Leg',
#    'plus_code': {'compound_code': 'G2FR+R6 Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G2FR+R6'},
#    'rating': 4.5,
#    'reference': 'ChIJ55z2kUelfDURRm5aBsQ7Leg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '88-6 Cheongdam-dong, Gangnam-gu'},
#   {'geometry': {'location': {'lat': 37.5209278, 'lng': 127.0376475},
#     'viewport': {'northeast': {'lat': 37.52227762989273,
#       'lng': 127.0389973298927},
#      'southwest': {'lat': 37.51957797010729, 'lng': 127.0362976701072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '1c72260c3a083aae14e9d6657bb63add86a8f610',
#    'name': '우리동네청년어부 청담점',
#    'place_id': 'ChIJm_UoMoqjfDURQn4zC2H93XE',
#    'plus_code': {'compound_code': 'G2CQ+93 Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G2CQ+93'},
#    'rating': 0,
#    'reference': 'ChIJm_UoMoqjfDURQn4zC2H93XE',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': 'Gangnam-gu, Nonhyeon-dong, 99번지 1층 101호'},
#   {'geometry': {'location': {'lat': 37.5237862, 'lng': 127.0518393},
#     'viewport': {'northeast': {'lat': 37.52513602989272,
#       'lng': 127.0531891298927},
#      'southwest': {'lat': 37.52243637010728, 'lng': 127.0504894701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '98813c4b6a78e566cbe5d1d5cc3166242d1b1521',
#    'name': '스시 카이신 (鮨海信)',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3036,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105308202664122538373">Andy S</a>'],
#      'photo_reference': 'CmRaAAAAzryaBhV8kwkuqAimZNQau12ooJC-Iz2AKLSfdH3yzewwBFG25C7Gx3HgF6jpeFP0uE5Uq9lig2IE0X9NB7Z_TYfvbtiMu2sijaeQ40C-jQfBmvPUcbjXwwmxgmHBw0lyEhB9gToqcD2VFpgVyR-lXgkxGhQHgCyf0s812neeeMogS9WYhpsr0w',
#      'width': 4048}],
#    'place_id': 'ChIJ4xj022SkfDURZmTEG2Lkg8I',
#    'plus_code': {'compound_code': 'G3F2+GP Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G3F2+GP'},
#    'rating': 4.8,
#    'reference': 'ChIJ4xj022SkfDURZmTEG2Lkg8I',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 16,
#    'vicinity': 'Gangnam-gu, Cheongdam-dong, Dosan-daero 100-gil, 12 우리빌딩 2F'},
#   {'geometry': {'location': {'lat': 37.5255957, 'lng': 127.0419331},
#     'viewport': {'northeast': {'lat': 37.52694552989272,
#       'lng': 127.0432829298927},
#      'southwest': {'lat': 37.52424587010727, 'lng': 127.0405832701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '2088a432155326de1888db80093514fbc6868cf3',
#    'name': 'Kojima',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103803069155565114071">Den Sunoo</a>'],
#      'photo_reference': 'CmRaAAAAddvZjNGvtyJ2iujB6MI6AFaSALpubltGjvu176wPsPreJAnvnAuuXiaQXuWuhurbv5l8pos9Ny_ngX_MbQZDkCbmzdQjXZZD0oxrlnIzk8lFUyXnO8iiRY71Futhz1pJEhBW1peH89w7vJM9f-cNAmneGhSylLHsgoZMScd7dQQ0hjlSqk8GvA',
#      'width': 4032}],
#    'place_id': 'ChIJG9GROXikfDUR7LwV7ihLKgA',
#    'plus_code': {'compound_code': 'G2GR+6Q Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G2GR+6Q'},
#    'price_level': 4,
#    'rating': 4.1,
#    'reference': 'ChIJG9GROXikfDUR7LwV7ihLKgA',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 90,
#    'vicinity': 'A 동 6 층, 21 Apgujeong-ro 60-gil, Gangnam-gu'},
#   {'geometry': {'location': {'lat': 37.5064685, 'lng': 127.050913},
#     'viewport': {'northeast': {'lat': 37.50781832989272,
#       'lng': 127.0522628298927},
#      'southwest': {'lat': 37.50511867010728, 'lng': 127.0495631701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '29b7e7e014749414aad1283c277c675ea4cca780',
#    'name': 'Sushi Sanwon',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1536,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103803069155565114071">Den Sunoo</a>'],
#      'photo_reference': 'CmRaAAAAbxIqFgEvEe9HpUEFnlgMpGmljYN1OPpxthLWTR9dKRnFuU_sitA3ZkC4dEWxD99RdDte0-Kwt6Bzd7UfHk_Bkkihpo6srRS8brN3XEthwk_eV4Zqq__jJ6W8P9LKlFtiEhBHLK6cdEE8H6zfWkrzrefaGhSLUvy8caUHpZCu4-wV40KkEcYdUQ',
#      'width': 2048}],
#    'place_id': 'ChIJgwxk4BGkfDURSnLnQ3uNUKU',
#    'plus_code': {'compound_code': 'G342+H9 Seoul, 서울특별시 South Korea',
#     'global_code': '8Q99G342+H9'},
#    'rating': 4.3,
#    'reference': 'ChIJgwxk4BGkfDURSnLnQ3uNUKU',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 121,
#    'vicinity': 'Gangnam-gu, Samseong-dong, Seolleung-ro 100-gil, 42 엘지선릉에클라트 1층 1호'}],
#  'status': 'OK'}

# %%
# def google_geo(srch_list,pois,radius):
srch_list = ["235 w van buren"]
pois = "restaurant"
radius=1000
records = pd.DataFrame()
gkey = "AIzaSyCfU1oUl3DFvbyDx3gT13kBUB2pNmt0MAk"
#     srch_list = ["91765","60607"]
# srch_list = ["walnut high school","235 west van buren"]
#     pois = "restaurants,subway station"
#     radius = 15000
pois = pois.split(",")
for s in srch_list:
    target_url = (f'https://maps.googleapis.com/maps/api/geocode/json?address={s}&key={gkey}')
    geo_data = requests.get(target_url).json()
    target_adr = geo_data["results"][0]["formatted_address"]
    lat = geo_data["results"][0]["geometry"]["location"]["lat"]
    lng = geo_data["results"][0]["geometry"]["location"]["lng"]
    target_coordinates = str(lat) + "," + str(lng)
    link = geo_data["results"][0]["place_id"]
    center_df = pd.DataFrame({"center":[s],"poi":["YOU ARE HERE"],"name":["YOU ARE HERE"],"address":[target_adr],"link":[link],"Y":[float(lat)],"X":[float(lng)]})
    records = records.append(center_df)
    for poi in pois:
        params = {
            "location": target_coordinates,
            "keyword": poi,
            "radius": radius,
        #     "type": target_type,
            "key": gkey
        }

        # base url
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

        # run a request using our params dictionary
        response = requests.get(base_url, params=params)
        places_data = response.json()
        n=0
        # while int(n) > len(places_data):
        while int(n) < len(places_data["results"]):
            try:
                price=places_data["results"][int(n)]["price_level"]
            except KeyError:
                price = "NA"
            try:
                link=places_data["results"][int(n)]["place_id"]
            except KeyError:
                link = "NA"
            try:
                score = places_data["results"][int(n)]["rating"]
            except KeyError:
                score = "NA"
            try:
                reviews = int(places_data["results"][int(n)]["user_ratings_total"])
            except KeyError:
                reviews = "NA"
            try:
                lat1 = places_data["results"][int(n)]["geometry"]["location"]["lat"]
            except KeyError:
                lat1 = "NA"
            try:
                lng1 = places_data["results"][int(n)]["geometry"]["location"]["lng"]
            except KeyError:
                lng1 = "NA"
            content = pd.DataFrame ({"center":target_adr,"poi":poi,
                                "name":[places_data["results"][int(n)]["name"]],
                                "score":score,
                                 "reviews":reviews,
                                 "price":price,
                                 "link":link,
                                "address":[places_data["results"][int(n)]["vicinity"]],
                                     "Y":[lat1],
                                     "X":[lng1]
        #                        "distance":distance,
        #                         "drive":duration,
        #                         "public":transit_dur,
        #                         "walk":walk_dur
                                    })
            records = records.append(content)
            n+=1
records.reset_index(drop = True,inplace = True)
records = records[["center","poi","name","score","reviews","price","price","link","address","X","Y"]]
records["link"]=records["link"].apply(lambda x: '<a href="https://www.google.com/maps/place/?q=place_id:{0}">link</a>'.format(x))
return(records)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-dc9001021416> in <module>
#      13     target_url = (f'https://maps.googleapis.com/maps/api/geocode/json?address={s}&key={gkey}')
#      14     geo_data = requests.get(target_url).json()
# ---> 15     target_adr = geo_data["results"][0]["formatted_address"]
#      16     lat = geo_data["results"][0]["geometry"]["location"]["lat"]
#      17     lng = geo_data["results"][0]["geometry"]["location"]["lng"]
#
# IndexError: list index out of range

# %%
geo_data
# Out:
# {'error_message': 'You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started',
#  'results': [],
#  'status': 'REQUEST_DENIED'}
